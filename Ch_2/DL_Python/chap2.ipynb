# %%
# %pip install tensorflow keras

# %%
from keras import layers

# %%
layer = layers.Dense(32, input_shape=(784,)) 
layer

# %%
from keras import models
from keras import layers

# %%
model = models.Sequential()
model.add(layers.Dense(32, input_shape=(784,)))
model.add(layers.Dense(32, activation='relu'))
model.add(layers.Dense(32, activation='relu', input_shape=(784,)))
model.add(layers.Dense(10, activation='softmax'))

# %%
input_tensor = layers.Input(shape=(784,))
x = layers.Dense(32, activation='relu')(input_tensor)
output_tensor = layers.Dense(10, activation='softmax')(x)
model = models.Model(inputs=input_tensor, outputs=output_tensor)
model.summary() #model.summary() is a helper in Keras/TensorFlow that shows a compact overview of a neural network model.

# %%
import numpy as np
from keras import optimizers

# create dummy training data to match the model input/output shapes
x_train = np.random.random((1000, 784)).astype('float32')
y_train = np.random.randint(10, size=(1000,))
target_tensor = np.eye(10, dtype='float32')[y_train]

model.compile(
	optimizer=optimizers.RMSprop(learning_rate=0.001),
	loss='categorical_crossentropy',
	metrics=['accuracy']
)
model.fit(x_train, target_tensor, epochs=10, batch_size=128)
