# %%
import torch
a = torch.ones(3)
a
# Out:
# tensor([1., 1., 1.])

# %%
a[1]
# Out:
# tensor(1.)

# %%
a.shape
# Out:
# torch.Size([3])

# %%
points = torch.tensor([[1, 2], [3, 4], [5, 6]])
# points = torch.zeros(3, 2)
points
# Out:
# tensor([[1, 2],
#         [3, 4],
#         [5, 6]])

# %%
points[0, 1]
# Out:
# tensor(2)

# %%
# Named tensors
img_t = torch.rand(3, 5, 5, names=('C', 'H', 'W'))
weights = torch.tensor([0.2126, 0.7152, 0.0722])
# Out:
# C:\Users\alokk\AppData\Local\Temp\ipykernel_23704\1309740320.py:2: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\c10/core/TensorImpl.h:1976.)
#   img_t = torch.rand(3, 5, 5, names=('C', 'H', 'W'))

# %%
unsqueezed_weights = weights.unsqueeze(-1).unsqueeze_(-1)
img_weights = (img_t * unsqueezed_weights)
batch_t = torch.stack([img_t.rename(None), img_t.rename(None)]).rename('B', 'C', 'H', 'W')
batch_weights = (batch_t * unsqueezed_weights)
img_gray_weighted = img_weights.sum(-3)
batch_gray_weighted = batch_weights.sum(-3)
batch_weights.shape, batch_t.shape, unsqueezed_weights.shape
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[11], line 3
#       1 unsqueezed_weights = weights.unsqueeze(-1).unsqueeze_(-1)
#       2 img_weights = (img_t * unsqueezed_weights)
# ----> 3 batch_t = torch.stack([img_t, img_t])
#       4 batch_weights = (batch_t * unsqueezed_weights)
#       5 img_gray_weighted = img_weights.sum(-3)
#       6 batch_gray_weighted = batch_weights.sum(-3)
#
# RuntimeError: aten::stack is not yet supported with named tensors. Please drop names via `tensor = tensor.rename(None)`, call the op with an unnamed tensor, and set names on the result of the operation.
